# %% [markdown]
# ## Reading Dataset:

# %%
# Importing necessary libraries
import pandas as pd

# Load the dataset
df = pd.read_csv('Datasets.csv')  # Load the dataset into a Pandas DataFrame

# Display basic information about the dataset
df  # reading Dataset
# Out:
#                                           ID      Sender_IP  Sender_Port  \
# 0       10.42.0.211-104.97.95.172-59522-80-6  192.168.2.112         2142
# 1      216.58.217.68-10.42.0.211-443-59345-6  147.32.84.170         2108
# 2        10.42.0.151-54.192.38.7-52510-443-6  147.32.84.170         3805
# 3      216.58.219.206-10.42.0.42-443-53294-6  147.32.84.180         3008
# 4           10.42.0.1-10.42.0.42-53-62597-17  147.32.84.160        11697
# ...                                      ...            ...          ...
# 5467    10.42.0.211-119.146.74.34-36834-80-6  192.168.4.121        51163
# 5468  172.217.10.227-10.42.0.151-443-55235-6  158.65.110.24        54167
# 5469   10.42.0.211-54.192.38.236-54577-443-6  147.32.84.180         1025
# 5470   10.42.0.211-104.88.89.135-41161-443-6  192.168.4.118         1910
# 5471   10.42.0.211-120.76.223.181-37272-83-6  147.32.84.170         2775
#
#             Target_IP  Target_Port  Transport_Protocol  Duration  AvgDuration  \
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Drop unnecessary columns or columns causing issues
data_processed = df.drop(['ID', 'Sender_IP', 'Target_IP'], axis=1)  # Remove columns not needed for analysis

# Splitting features and target variable
X = data_processed.drop('class', axis=1)  # Features (independent variables)
y = data_processed['class']  # Target variable (dependent variable)

# Scale the features
scaler = StandardScaler()  # Initialize a scaler to standardize the features
X_scaled = scaler.fit_transform(X)  # Scale the features to have a mean of 0 and variance of 1

# Splitting data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
# Split the dataset into training (70%) and testing (30%) sets

# %% [markdown]
# ##  Training, Prediction, and Evaluation :

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the Random Forest Classifier model
model = RandomForestClassifier(n_estimators=100, random_state=42)  # Initialize Random Forest Classifier

# Train the model
model.fit(X_train, y_train) # Train the model using the training data

# Prediction on the test set
predict = model.predict(X_test)  # Make predictions on the test set

# Model Evaluation
accuracy = accuracy_score(y_test, predict)  # Calculate accuracy
print(f"Accuracy: {accuracy}")  # Print the accuracy of the model

# Additional evaluation metrics
print("Classification Report:")
print(classification_report(y_test, predictions))  # Display precision, recall, F1-score, and support for each class

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))  # Display the confusion matrix
# Out:
# Accuracy: 0.8788063337393422
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84       611
#            1       0.90      0.91      0.90      1031
#
#     accuracy                           0.88      1642
#    macro avg       0.87      0.87      0.87      1642
# weighted avg       0.88      0.88      0.88      1642
#
# Confusion Matrix:
# [[507 104]
#  [ 95 936]]
